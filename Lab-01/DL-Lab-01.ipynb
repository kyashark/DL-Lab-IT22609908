# %%
import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
import pandas as pd

# %% [markdown]
# **Task 1**

# %% [markdown]
# **1) Random 4×4 array (Exponential Distribution)**

# %%
arr = np.random.exponential(scale=1.0, size=(4,4))
print(arr)
# Out:
# [[1.05257892 0.46402509 0.41186521 0.46979283]
#  [0.39376168 1.281034   0.52251716 0.06779715]
#  [0.51259848 0.59647173 0.99235105 0.12927594]
#  [1.23280306 1.26901762 2.38911766 1.74873501]]

# %% [markdown]
# **2) Compare Exponential, Uniform, Normal Distributions**

# %%
# Create arrays
exp_data = np.random.exponential(scale=1.0, size=(100000, 1))
uni_data = np.random.rand(100000, 1)       # Uniform
norm_data = np.random.normal(size=(100000, 1))  # Normal

# %%
# Plot histograms
plt.figure(figsize=(8,5))
plt.hist(exp_data, density=True, bins=100, histtype="step", label="Exponential")
plt.hist(uni_data, density=True, bins=100, histtype="step", label="Uniform")
plt.hist(norm_data, density=True, bins=100, histtype="step", label="Normal")

# Customize
plt.xlim(-2, 6)
plt.ylim(0, 1.5)
plt.legend(loc="upper right")
plt.title("Random Distributions Comparison")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# **3) 3D Plot of Z = X² + Y²**

# %%
# Create X and Y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate Z
Z = X**2 + Y**2

# %%
# Make 3D plot
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# Labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# **4) Pearson & Spearman Correlation Heatmaps**

# %%
# Load dataset from seaborn tutorial
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv

# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')
print(df.head())
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# Select only the required columns
stats = df[["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]]
print(stats.head())
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1  45      49       49       65       65     45
# 2  60      62       63       80       80     60
# 3  80      82       83      100      100     80
# 4  39      52       43       60       50     65
# 5  58      64       58       80       65     80

# %%
# Calculate correlations
pearson_corr = stats.corr(method="pearson")
spearman_corr = stats.corr(method="spearman")

print("Pearson Correlation:\n", pearson_corr)
print("\nSpearman Correlation:\n", spearman_corr)
# Out:
# Pearson Correlation:
#                 HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.306768  0.119782  0.236649  0.490978 -0.040939
# Attack   0.306768  1.000000  0.491965  0.146312  0.369069  0.194701
# Defense  0.119782  0.491965  1.000000  0.187569  0.139912 -0.053252
# Sp. Atk  0.236649  0.146312  0.187569  1.000000  0.522907  0.411516
# Sp. Def  0.490978  0.369069  0.139912  0.522907  1.000000  0.392656
# Speed   -0.040939  0.194701 -0.053252  0.411516  0.392656  1.000000
#
# Spearman Correlation:
#                 HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.539356  0.390014  0.363993  0.566837  0.054014
# Attack   0.539356  1.000000  0.541506  0.161862  0.386198  0.226590
# Defense  0.390014  0.541506  1.000000  0.258751  0.250028 -0.033235
# Sp. Atk  0.363993  0.161862  0.258751  1.000000  0.561665  0.384759
# Sp. Def  0.566837  0.386198  0.250028  0.561665  1.000000  0.403588
# ...

# %%
# Visualize with heatmaps
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
sns.heatmap(pearson_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Pearson Correlation")

plt.subplot(1, 2, 2)
sns.heatmap(spearman_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Spearman Correlation")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Task 2**

# %%
# Load Dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63beaf0a-a7af-4118-a833-c2f3794f2c34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63beaf0a-a7af-4118-a833-c2f3794f2c34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Au_nanoparticle_dataset (1).csv')
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %% [markdown]
# **1) Filter columns**

# %%
new_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

# %% [markdown]
# **2) Display the first 20 samples**

# %%
new_df.head(20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %% [markdown]
# **3) Calculate statistics**

# %%
# Mean
mean_values = new_df.mean()

# Standard deviation
std_values = new_df.std()

# Quartiles
quartiles = new_df.quantile([0.25, 0.5, 0.75])

print("Mean values:\n", mean_values)
print("\nStandard deviation:\n", std_values)
print("\nQuartiles:\n", quartiles)
# Out:
# Mean values:
#  N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64
#
# Standard deviation:
#  N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# dtype: float64
#
# Quartiles:
#        N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %% [markdown]
# **4) Plot histograms in 1x4 layout**

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

for i, col in enumerate(new_df.columns):
    axes[i].hist(new_df[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **5) Pairplot using Seaborn**

# %%
sns.pairplot(new_df)
plt.show()

# %% [markdown]
# **6) PairGrid with custom diagonal and lower plots**

# %%
# new_df contains only the 4 features
g = sns.PairGrid(new_df)

# %%
# Upper triangle: histograms
g.map_upper(sns.histplot)

# %%
# Diagonal: histogram + KDE
g.map_diag(lambda x, **kwargs: sns.histplot(x, kde=True, **kwargs))

# %%
# Lower triangle: bivariate KDE
g.map_lower(sns.kdeplot, fill=True)

# %%
plt.show()
